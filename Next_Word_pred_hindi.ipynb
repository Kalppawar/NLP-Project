# %%
#pip install tensorflow==2.5
# Out:
# Collecting tensorflow==2.5
#   Downloading tensorflow-2.5.0-cp37-cp37m-manylinux2010_x86_64.whl (454.3 MB)
#      |████████████████████████████████| 454.3 MB 15 kB/s
# Collecting flatbuffers~=1.12.0
#   Downloading flatbuffers-1.12-py2.py3-none-any.whl (15 kB)
# Collecting gast==0.4.0
#   Downloading gast-0.4.0-py3-none-any.whl (9.8 kB)
# Collecting typing-extensions~=3.7.4
#   Downloading typing_extensions-3.7.4.3-py3-none-any.whl (22 kB)
# Collecting grpcio~=1.34.0
#   Downloading grpcio-1.34.1-cp37-cp37m-manylinux2014_x86_64.whl (4.0 MB)
#      |████████████████████████████████| 4.0 MB 41.1 MB/s
# Requirement already satisfied: protobuf>=3.9.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.5) (3.17.3)
# Collecting wrapt~=1.12.1
#   Downloading wrapt-1.12.1.tar.gz (27 kB)
# Collecting absl-py~=0.10
#   Downloading absl_py-0.15.0-py3-none-any.whl (132 kB)
#      |████████████████████████████████| 132 kB 30.6 MB/s
# Requirement already satisfied: tensorboard~=2.5 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.5) (2.8.0)
# Collecting numpy~=1.19.2
#   Downloading numpy-1.19.5-cp37-cp37m-manylinux2010_x86_64.whl (14.8 MB)
#      |████████████████████████████████| 14.8 MB 37.8 MB/s
# Requirement already satisfied: opt-einsum~=3.3.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.5) (3.3.0)
# Collecting tensorflow-estimator<2.6.0,>=2.5.0rc0
#   Downloading tensorflow_estimator-2.5.0-py2.py3-none-any.whl (462 kB)
#      |████████████████████████████████| 462 kB 51.9 MB/s
# Requirement already satisfied: astunparse~=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.5) (1.6.3)
# Requirement already satisfied: termcolor~=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.5) (1.1.0)
# Collecting keras-nightly~=2.5.0.dev
#   Downloading keras_nightly-2.5.0.dev2021032900-py2.py3-none-any.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 47.1 MB/s
# Requirement already satisfied: h5py~=3.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.5) (3.1.0)
# Requirement already satisfied: wheel~=0.35 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.5) (0.37.1)
# Requirement already satisfied: keras-preprocessing~=1.1.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.5) (1.1.2)
# Requirement already satisfied: google-pasta~=0.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.5) (0.2.0)
# Requirement already satisfied: six~=1.15.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.5) (1.15.0)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py~=3.1.0->tensorflow==2.5) (1.5.2)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.5->tensorflow==2.5) (2.23.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.5->tensorflow==2.5) (3.3.6)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.5->tensorflow==2.5) (0.4.6)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.5->tensorflow==2.5) (1.0.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.5->tensorflow==2.5) (1.8.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.5->tensorflow==2.5) (0.6.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.5->tensorflow==2.5) (1.35.0)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.5->tensorflow==2.5) (57.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard~=2.5->tensorflow==2.5) (4.8)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard~=2.5->tensorflow==2.5) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard~=2.5->tensorflow==2.5) (4.2.4)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.5->tensorflow==2.5) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard~=2.5->tensorflow==2.5) (4.11.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard~=2.5->tensorflow==2.5) (3.8.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard~=2.5->tensorflow==2.5) (0.4.8)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow==2.5) (2021.10.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow==2.5) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow==2.5) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow==2.5) (3.0.4)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.5->tensorflow==2.5) (3.2.0)
# Building wheels for collected packages: wrapt
#   Building wheel for wrapt (setup.py) ... done
#   Created wheel for wrapt: filename=wrapt-1.12.1-cp37-cp37m-linux_x86_64.whl size=68719 sha256=1bd0d7b1d5c98374284e2da61e86a73f7e2a882d86ee5a66cf70c80a5eb7ff46
#   Stored in directory: /root/.cache/pip/wheels/62/76/4c/aa25851149f3f6d9785f6c869387ad82b3fd37582fa8147ac6
# Successfully built wrapt
# Installing collected packages: typing-extensions, numpy, grpcio, absl-py, wrapt, tensorflow-estimator, keras-nightly, gast, flatbuffers, tensorflow
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing-extensions 4.1.1
#     Uninstalling typing-extensions-4.1.1:
#       Successfully uninstalled typing-extensions-4.1.1
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.21.5
#     Uninstalling numpy-1.21.5:
#       Successfully uninstalled numpy-1.21.5
#   Attempting uninstall: grpcio
#     Found existing installation: grpcio 1.44.0
#     Uninstalling grpcio-1.44.0:
#       Successfully uninstalled grpcio-1.44.0
#   Attempting uninstall: absl-py
#     Found existing installation: absl-py 1.0.0
#     Uninstalling absl-py-1.0.0:
#       Successfully uninstalled absl-py-1.0.0
#   Attempting uninstall: wrapt
#     Found existing installation: wrapt 1.14.0
#     Uninstalling wrapt-1.14.0:
#       Successfully uninstalled wrapt-1.14.0
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.8.0
#     Uninstalling tensorflow-estimator-2.8.0:
#       Successfully uninstalled tensorflow-estimator-2.8.0
#   Attempting uninstall: gast
#     Found existing installation: gast 0.5.3
#     Uninstalling gast-0.5.3:
#       Successfully uninstalled gast-0.5.3
#   Attempting uninstall: flatbuffers
#     Found existing installation: flatbuffers 2.0
#     Uninstalling flatbuffers-2.0:
#       Successfully uninstalled flatbuffers-2.0
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.8.0
#     Uninstalling tensorflow-2.8.0:
#       Successfully uninstalled tensorflow-2.8.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# albumentations 0.1.12 requires imgaug<0.2.7,>=0.2.5, but you have imgaug 0.2.9 which is incompatible.
# Successfully installed absl-py-0.15.0 flatbuffers-1.12 gast-0.4.0 grpcio-1.34.1 keras-nightly-2.5.0.dev2021032900 numpy-1.19.5 tensorflow-2.5.0 tensorflow-estimator-2.5.0 typing-extensions-3.7.4.3 wrapt-1.12.1

# %%
filename = "D21.txt"
data = open(filename, 'r', encoding='utf-8').read()
print(data[:300])
# Out:
# "ये लंदन है, दुनिया का सबसे बड़ा शहर।"
# "मैं 22 वर्ष से यहाँ रह रहा हूँ, रोज़ाना इसी सड़क से गुजरता हूँ और रोज़ाना ये सड़क मुझसे मेरा नाम पूछती है।"
# ये पूछती है कि चौधरी बलदेव सिंह कौन है? कहां से आया है? क्यों आया है?
# "अब मैं इसे क्या जवाब दूँ, आधी उम्र गुज़ारने के बाद भी ये धरती मेरे लिए अजनबी है और

# %%
# pip install gradio

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM, Bidirectional
from tensorflow.keras.layers import Embedding
from tensorflow.keras.callbacks import ModelCheckpoint
import numpy as np
# import gradio as gr

# %%
def generate_seq(model, tokenizer, max_length, seed_text, n_words):
	in_text = seed_text
    # generate a fixed number of words
	for _ in range(n_words):
        # encode the text as integer
		encoded = tokenizer.texts_to_sequences([in_text])[0]
		# pre-pad sequences to a fixed length
		encoded = pad_sequences([encoded], maxlen=max_length, padding='pre')
		# predict probabilities for each word
		yhat = np.argmax(model.predict(encoded), axis=-1)
		# map predicted word index to word
		out_word = ''
		for word, index in tokenizer.word_index.items():
			if index == yhat:
				out_word = word
				break
		# append to input
		in_text += ' ' + out_word
	return in_text

def generate(seed_text,n):
  return generate_seq(model,tokenizer,max_length-1,seed_text,int(n))

# %%
# integer encode sequences of words
tokenizer = Tokenizer()
tokenizer.fit_on_texts([data])
encoded = tokenizer.texts_to_sequences([data])[0]

# %%
# retrieve vocabulary size
vocab_size = len(tokenizer.word_index) + 1
#print('Vocabulary Size: %d' % vocab_size)
# encode 2 words -> 1 word
sequences = list()
for i in range(2, len(encoded)):
	sequence = encoded[i-2:i+1]
	sequences.append(sequence)

# %%
print('Total Sequences: %d' % len(sequences))
# pad sequences
max_length = max([len(seq) for seq in sequences])
sequences = pad_sequences(sequences, maxlen=max_length, padding='pre')
print('Max Sequence Length: %d' % max_length)
# Out:
# Total Sequences: 14522
# Max Sequence Length: 3

# %%
# split into input and output elements
from numpy import array

sequences = array(sequences)
X, y = sequences[:,:-1],sequences[:,-1]

#print(X)
y = to_categorical(y, num_classes=vocab_size)
#print(y)

# %%
# define model
model=Sequential()
model.add(Embedding(vocab_size, 10, input_length=max_length-1))
model.add(Bidirectional(LSTM(50)))
model.add(Dense(vocab_size, activation='softmax'))
print(model.summary())
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 2, 10)             25730
# _________________________________________________________________
# bidirectional (Bidirectional (None, 100)               24400
# _________________________________________________________________
# dense (Dense)                (None, 2573)              259873
# =================================================================
# Total params: 310,003
# Trainable params: 310,003
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
# define the checkpoint
filepath="weights-improvement-{epoch:02d}-{loss:.4f}-bigger.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='loss', verbose=1, save_best_only=True, mode='min')
callbacks_list = [checkpoint]
# fit the model
#uncomment the below code to train the model
history = model.fit(X, y, epochs=250, verbose=2, callbacks=callbacks_list)
# evaluate model
# Out:
# Epoch 1/250
# 454/454 - 8s - loss: 6.9340 - accuracy: 0.0266
#
# Epoch 00001: loss improved from inf to 6.93398, saving model to weights-improvement-01-6.9340-bigger.hdf5
# Epoch 2/250
# 454/454 - 4s - loss: 6.4818 - accuracy: 0.0281
#
# Epoch 00002: loss improved from 6.93398 to 6.48185, saving model to weights-improvement-02-6.4818-bigger.hdf5
# Epoch 3/250
# 454/454 - 4s - loss: 6.3790 - accuracy: 0.0320
#
# Epoch 00003: loss improved from 6.48185 to 6.37897, saving model to weights-improvement-03-6.3790-bigger.hdf5
# Epoch 4/250
# 454/454 - 8s - loss: 6.2740 - accuracy: 0.0390
#
# Epoch 00004: loss improved from 6.37897 to 6.27401, saving model to weights-improvement-04-6.2740-bigger.hdf5
# Epoch 5/250
# 454/454 - 8s - loss: 6.1727 - accuracy: 0.0409
#
# Epoch 00005: loss improved from 6.27401 to 6.17275, saving model to weights-improvement-05-6.1727-bigger.hdf5
# Epoch 6/250
# 454/454 - 11s - loss: 6.0857 - accuracy: 0.0430
#
# Epoch 00006: loss improved from 6.17275 to 6.08573, saving model to weights-improvement-06-6.0857-bigger.hdf5
# Epoch 7/250
# 454/454 - 9s - loss: 6.0037 - accuracy: 0.0470
#
# Epoch 00007: loss improved from 6.08573 to 6.00374, saving model to weights-improvement-07-6.0037-bigger.hdf5
# Epoch 8/250
# 454/454 - 8s - loss: 5.9196 - accuracy: 0.0514
#
# Epoch 00008: loss improved from 6.00374 to 5.91957, saving model to weights-improvement-08-5.9196-bigger.hdf5
# Epoch 9/250
# 454/454 - 7s - loss: 5.8335 - accuracy: 0.0549
#
# Epoch 00009: loss improved from 5.91957 to 5.83346, saving model to weights-improvement-09-5.8335-bigger.hdf5
# Epoch 10/250
# 454/454 - 4s - loss: 5.7431 - accuracy: 0.0594
#
# Epoch 00010: loss improved from 5.83346 to 5.74305, saving model to weights-improvement-10-5.7431-bigger.hdf5
# Epoch 11/250
# 454/454 - 4s - loss: 5.6482 - accuracy: 0.0653
#
# Epoch 00011: loss improved from 5.74305 to 5.64818, saving model to weights-improvement-11-5.6482-bigger.hdf5
# Epoch 12/250
# 454/454 - 4s - loss: 5.5501 - accuracy: 0.0698
#
# Epoch 00012: loss improved from 5.64818 to 5.55010, saving model to weights-improvement-12-5.5501-bigger.hdf5
# Epoch 13/250
# 454/454 - 4s - loss: 5.4423 - accuracy: 0.0771
#
# Epoch 00013: loss improved from 5.55010 to 5.44228, saving model to weights-improvement-13-5.4423-bigger.hdf5
# Epoch 14/250
# 454/454 - 4s - loss: 5.3277 - accuracy: 0.0847
#
# Epoch 00014: loss improved from 5.44228 to 5.32775, saving model to weights-improvement-14-5.3277-bigger.hdf5
# Epoch 15/250
# 454/454 - 4s - loss: 5.2058 - accuracy: 0.0908
#
# Epoch 00015: loss improved from 5.32775 to 5.20578, saving model to weights-improvement-15-5.2058-bigger.hdf5
# Epoch 16/250
# 454/454 - 4s - loss: 5.0818 - accuracy: 0.1001
#
# Epoch 00016: loss improved from 5.20578 to 5.08180, saving model to weights-improvement-16-5.0818-bigger.hdf5
# Epoch 17/250
# 454/454 - 4s - loss: 4.9588 - accuracy: 0.1069
#
# Epoch 00017: loss improved from 5.08180 to 4.95877, saving model to weights-improvement-17-4.9588-bigger.hdf5
# Epoch 18/250
# 454/454 - 5s - loss: 4.8386 - accuracy: 0.1206
#
# Epoch 00018: loss improved from 4.95877 to 4.83860, saving model to weights-improvement-18-4.8386-bigger.hdf5
# Epoch 19/250
# 454/454 - 4s - loss: 4.7198 - accuracy: 0.1318
#
# Epoch 00019: loss improved from 4.83860 to 4.71982, saving model to weights-improvement-19-4.7198-bigger.hdf5
# Epoch 20/250
# 454/454 - 5s - loss: 4.6079 - accuracy: 0.1417
#
# Epoch 00020: loss improved from 4.71982 to 4.60794, saving model to weights-improvement-20-4.6079-bigger.hdf5
# Epoch 21/250
# 454/454 - 4s - loss: 4.4940 - accuracy: 0.1506
#
# Epoch 00021: loss improved from 4.60794 to 4.49403, saving model to weights-improvement-21-4.4940-bigger.hdf5
# Epoch 22/250
# 454/454 - 4s - loss: 4.3862 - accuracy: 0.1654
#
# Epoch 00022: loss improved from 4.49403 to 4.38625, saving model to weights-improvement-22-4.3862-bigger.hdf5
# Epoch 23/250
# 454/454 - 4s - loss: 4.2767 - accuracy: 0.1795
#
# Epoch 00023: loss improved from 4.38625 to 4.27674, saving model to weights-improvement-23-4.2767-bigger.hdf5
# Epoch 24/250
# 454/454 - 5s - loss: 4.1706 - accuracy: 0.1949
#
# Epoch 00024: loss improved from 4.27674 to 4.17056, saving model to weights-improvement-24-4.1706-bigger.hdf5
# Epoch 25/250
# 454/454 - 5s - loss: 4.0661 - accuracy: 0.2079
#
# Epoch 00025: loss improved from 4.17056 to 4.06609, saving model to weights-improvement-25-4.0661-bigger.hdf5
# Epoch 26/250
# 454/454 - 5s - loss: 3.9672 - accuracy: 0.2215
#
# Epoch 00026: loss improved from 4.06609 to 3.96719, saving model to weights-improvement-26-3.9672-bigger.hdf5
# Epoch 27/250
# 454/454 - 5s - loss: 3.8680 - accuracy: 0.2328
#
# Epoch 00027: loss improved from 3.96719 to 3.86799, saving model to weights-improvement-27-3.8680-bigger.hdf5
# Epoch 28/250
# 454/454 - 4s - loss: 3.7736 - accuracy: 0.2482
#
# Epoch 00028: loss improved from 3.86799 to 3.77355, saving model to weights-improvement-28-3.7736-bigger.hdf5
# Epoch 29/250
# 454/454 - 4s - loss: 3.6815 - accuracy: 0.2598
#
# Epoch 00029: loss improved from 3.77355 to 3.68149, saving model to weights-improvement-29-3.6815-bigger.hdf5
# Epoch 30/250
# 454/454 - 5s - loss: 3.5939 - accuracy: 0.2745
#
# Epoch 00030: loss improved from 3.68149 to 3.59392, saving model to weights-improvement-30-3.5939-bigger.hdf5
# Epoch 31/250
# 454/454 - 5s - loss: 3.5100 - accuracy: 0.2865
#
# Epoch 00031: loss improved from 3.59392 to 3.50999, saving model to weights-improvement-31-3.5100-bigger.hdf5
# Epoch 32/250
# 454/454 - 4s - loss: 3.4297 - accuracy: 0.2981
#
# Epoch 00032: loss improved from 3.50999 to 3.42974, saving model to weights-improvement-32-3.4297-bigger.hdf5
# Epoch 33/250
# 454/454 - 4s - loss: 3.3522 - accuracy: 0.3129
#
# Epoch 00033: loss improved from 3.42974 to 3.35219, saving model to weights-improvement-33-3.3522-bigger.hdf5
# Epoch 34/250
# 454/454 - 5s - loss: 3.2752 - accuracy: 0.3272
#
# Epoch 00034: loss improved from 3.35219 to 3.27519, saving model to weights-improvement-34-3.2752-bigger.hdf5
# Epoch 35/250
# 454/454 - 4s - loss: 3.2075 - accuracy: 0.3343
#
# Epoch 00035: loss improved from 3.27519 to 3.20745, saving model to weights-improvement-35-3.2075-bigger.hdf5
# Epoch 36/250
# 454/454 - 5s - loss: 3.1380 - accuracy: 0.3425
#
# Epoch 00036: loss improved from 3.20745 to 3.13802, saving model to weights-improvement-36-3.1380-bigger.hdf5
# Epoch 37/250
# 454/454 - 4s - loss: 3.0724 - accuracy: 0.3582
#
# Epoch 00037: loss improved from 3.13802 to 3.07241, saving model to weights-improvement-37-3.0724-bigger.hdf5
# Epoch 38/250
# 454/454 - 4s - loss: 3.0074 - accuracy: 0.3665
#
# Epoch 00038: loss improved from 3.07241 to 3.00738, saving model to weights-improvement-38-3.0074-bigger.hdf5
# Epoch 39/250
# 454/454 - 4s - loss: 2.9481 - accuracy: 0.3764
#
# Epoch 00039: loss improved from 3.00738 to 2.94812, saving model to weights-improvement-39-2.9481-bigger.hdf5
# Epoch 40/250
# 454/454 - 5s - loss: 2.8893 - accuracy: 0.3870
#
# Epoch 00040: loss improved from 2.94812 to 2.88933, saving model to weights-improvement-40-2.8893-bigger.hdf5
# Epoch 41/250
# 454/454 - 4s - loss: 2.8350 - accuracy: 0.3942
#
# Epoch 00041: loss improved from 2.88933 to 2.83505, saving model to weights-improvement-41-2.8350-bigger.hdf5
# Epoch 42/250
# 454/454 - 4s - loss: 2.7795 - accuracy: 0.3993
#
# Epoch 00042: loss improved from 2.83505 to 2.77946, saving model to weights-improvement-42-2.7795-bigger.hdf5
# Epoch 43/250
# 454/454 - 4s - loss: 2.7282 - accuracy: 0.4105
#
# Epoch 00043: loss improved from 2.77946 to 2.72819, saving model to weights-improvement-43-2.7282-bigger.hdf5
# Epoch 44/250
# 454/454 - 4s - loss: 2.6775 - accuracy: 0.4221
#
# Epoch 00044: loss improved from 2.72819 to 2.67754, saving model to weights-improvement-44-2.6775-bigger.hdf5
# Epoch 45/250
# 454/454 - 4s - loss: 2.6296 - accuracy: 0.4262
#
# Epoch 00045: loss improved from 2.67754 to 2.62958, saving model to weights-improvement-45-2.6296-bigger.hdf5
# Epoch 46/250
# 454/454 - 4s - loss: 2.5812 - accuracy: 0.4356
#
# Epoch 00046: loss improved from 2.62958 to 2.58119, saving model to weights-improvement-46-2.5812-bigger.hdf5
# Epoch 47/250
# 454/454 - 4s - loss: 2.5381 - accuracy: 0.4407
#
# Epoch 00047: loss improved from 2.58119 to 2.53809, saving model to weights-improvement-47-2.5381-bigger.hdf5
# Epoch 48/250
# 454/454 - 5s - loss: 2.4950 - accuracy: 0.4501
#
# Epoch 00048: loss improved from 2.53809 to 2.49498, saving model to weights-improvement-48-2.4950-bigger.hdf5
# Epoch 49/250
# 454/454 - 4s - loss: 2.4518 - accuracy: 0.4581
#
# Epoch 00049: loss improved from 2.49498 to 2.45178, saving model to weights-improvement-49-2.4518-bigger.hdf5
# Epoch 50/250
# 454/454 - 5s - loss: 2.4118 - accuracy: 0.4620
#
# Epoch 00050: loss improved from 2.45178 to 2.41178, saving model to weights-improvement-50-2.4118-bigger.hdf5
# Epoch 51/250
# 454/454 - 4s - loss: 2.3730 - accuracy: 0.4731
#
# Epoch 00051: loss improved from 2.41178 to 2.37305, saving model to weights-improvement-51-2.3730-bigger.hdf5
# Epoch 52/250
# 454/454 - 6s - loss: 2.3355 - accuracy: 0.4776
#
# Epoch 00052: loss improved from 2.37305 to 2.33551, saving model to weights-improvement-52-2.3355-bigger.hdf5
# Epoch 53/250
# 454/454 - 6s - loss: 2.2981 - accuracy: 0.4862
#
# Epoch 00053: loss improved from 2.33551 to 2.29809, saving model to weights-improvement-53-2.2981-bigger.hdf5
# Epoch 54/250
# 454/454 - 4s - loss: 2.2628 - accuracy: 0.4928
#
# Epoch 00054: loss improved from 2.29809 to 2.26281, saving model to weights-improvement-54-2.2628-bigger.hdf5
# Epoch 55/250
# 454/454 - 4s - loss: 2.2273 - accuracy: 0.4955
#
# Epoch 00055: loss improved from 2.26281 to 2.22731, saving model to weights-improvement-55-2.2273-bigger.hdf5
# Epoch 56/250
# 454/454 - 5s - loss: 2.1959 - accuracy: 0.5041
#
# Epoch 00056: loss improved from 2.22731 to 2.19592, saving model to weights-improvement-56-2.1959-bigger.hdf5
# Epoch 57/250
# 454/454 - 5s - loss: 2.1634 - accuracy: 0.5083
#
# Epoch 00057: loss improved from 2.19592 to 2.16343, saving model to weights-improvement-57-2.1634-bigger.hdf5
# Epoch 58/250
# 454/454 - 4s - loss: 2.1298 - accuracy: 0.5131
#
# Epoch 00058: loss improved from 2.16343 to 2.12977, saving model to weights-improvement-58-2.1298-bigger.hdf5
# Epoch 59/250
# 454/454 - 4s - loss: 2.1002 - accuracy: 0.5196
#
# Epoch 00059: loss improved from 2.12977 to 2.10024, saving model to weights-improvement-59-2.1002-bigger.hdf5
# Epoch 60/250
# 454/454 - 5s - loss: 2.0725 - accuracy: 0.5216
#
# Epoch 00060: loss improved from 2.10024 to 2.07250, saving model to weights-improvement-60-2.0725-bigger.hdf5
# Epoch 61/250
# 454/454 - 5s - loss: 2.0427 - accuracy: 0.5306
#
# Epoch 00061: loss improved from 2.07250 to 2.04271, saving model to weights-improvement-61-2.0427-bigger.hdf5
# Epoch 62/250
# 454/454 - 5s - loss: 2.0149 - accuracy: 0.5333
#
# Epoch 00062: loss improved from 2.04271 to 2.01492, saving model to weights-improvement-62-2.0149-bigger.hdf5
# Epoch 63/250
# 454/454 - 5s - loss: 1.9896 - accuracy: 0.5358
#
# Epoch 00063: loss improved from 2.01492 to 1.98962, saving model to weights-improvement-63-1.9896-bigger.hdf5
# Epoch 64/250
# 454/454 - 5s - loss: 1.9637 - accuracy: 0.5447
#
# Epoch 00064: loss improved from 1.98962 to 1.96371, saving model to weights-improvement-64-1.9637-bigger.hdf5
# Epoch 65/250
# 454/454 - 5s - loss: 1.9363 - accuracy: 0.5485
#
# Epoch 00065: loss improved from 1.96371 to 1.93631, saving model to weights-improvement-65-1.9363-bigger.hdf5
# Epoch 66/250
# 454/454 - 5s - loss: 1.9128 - accuracy: 0.5487
#
# Epoch 00066: loss improved from 1.93631 to 1.91277, saving model to weights-improvement-66-1.9128-bigger.hdf5
# Epoch 67/250
# 454/454 - 5s - loss: 1.8876 - accuracy: 0.5544
#
# Epoch 00067: loss improved from 1.91277 to 1.88763, saving model to weights-improvement-67-1.8876-bigger.hdf5
# Epoch 68/250
# 454/454 - 5s - loss: 1.8668 - accuracy: 0.5594
#
# Epoch 00068: loss improved from 1.88763 to 1.86677, saving model to weights-improvement-68-1.8668-bigger.hdf5
# Epoch 69/250
# 454/454 - 5s - loss: 1.8419 - accuracy: 0.5628
#
# Epoch 00069: loss improved from 1.86677 to 1.84194, saving model to weights-improvement-69-1.8419-bigger.hdf5
# Epoch 70/250
# 454/454 - 5s - loss: 1.8208 - accuracy: 0.5682
#
# Epoch 00070: loss improved from 1.84194 to 1.82082, saving model to weights-improvement-70-1.8208-bigger.hdf5
# Epoch 71/250
# 454/454 - 5s - loss: 1.7990 - accuracy: 0.5699
#
# Epoch 00071: loss improved from 1.82082 to 1.79896, saving model to weights-improvement-71-1.7990-bigger.hdf5
# Epoch 72/250
# 454/454 - 5s - loss: 1.7800 - accuracy: 0.5746
#
# Epoch 00072: loss improved from 1.79896 to 1.77998, saving model to weights-improvement-72-1.7800-bigger.hdf5
# Epoch 73/250
# 454/454 - 5s - loss: 1.7565 - accuracy: 0.5749
#
# Epoch 00073: loss improved from 1.77998 to 1.75650, saving model to weights-improvement-73-1.7565-bigger.hdf5
# Epoch 74/250
# 454/454 - 5s - loss: 1.7388 - accuracy: 0.5784
#
# Epoch 00074: loss improved from 1.75650 to 1.73878, saving model to weights-improvement-74-1.7388-bigger.hdf5
# Epoch 75/250
# 454/454 - 5s - loss: 1.7183 - accuracy: 0.5808
#
# Epoch 00075: loss improved from 1.73878 to 1.71826, saving model to weights-improvement-75-1.7183-bigger.hdf5
# Epoch 76/250
# 454/454 - 5s - loss: 1.6996 - accuracy: 0.5877
#
# Epoch 00076: loss improved from 1.71826 to 1.69962, saving model to weights-improvement-76-1.6996-bigger.hdf5
# Epoch 77/250
# 454/454 - 4s - loss: 1.6806 - accuracy: 0.5908
#
# Epoch 00077: loss improved from 1.69962 to 1.68059, saving model to weights-improvement-77-1.6806-bigger.hdf5
# Epoch 78/250
# 454/454 - 4s - loss: 1.6634 - accuracy: 0.5936
#
# Epoch 00078: loss improved from 1.68059 to 1.66335, saving model to weights-improvement-78-1.6634-bigger.hdf5
# Epoch 79/250
# 454/454 - 5s - loss: 1.6460 - accuracy: 0.5982
#
# Epoch 00079: loss improved from 1.66335 to 1.64597, saving model to weights-improvement-79-1.6460-bigger.hdf5
# Epoch 80/250
# 454/454 - 4s - loss: 1.6302 - accuracy: 0.5993
#
# Epoch 00080: loss improved from 1.64597 to 1.63018, saving model to weights-improvement-80-1.6302-bigger.hdf5
# Epoch 81/250
# 454/454 - 5s - loss: 1.6121 - accuracy: 0.6001
#
# Epoch 00081: loss improved from 1.63018 to 1.61207, saving model to weights-improvement-81-1.6121-bigger.hdf5
# Epoch 82/250
# 454/454 - 5s - loss: 1.5952 - accuracy: 0.6073
#
# Epoch 00082: loss improved from 1.61207 to 1.59520, saving model to weights-improvement-82-1.5952-bigger.hdf5
# Epoch 83/250
# 454/454 - 5s - loss: 1.5810 - accuracy: 0.6068
#
# Epoch 00083: loss improved from 1.59520 to 1.58102, saving model to weights-improvement-83-1.5810-bigger.hdf5
# Epoch 84/250
# 454/454 - 4s - loss: 1.5659 - accuracy: 0.6070
#
# Epoch 00084: loss improved from 1.58102 to 1.56586, saving model to weights-improvement-84-1.5659-bigger.hdf5
# Epoch 85/250
# 454/454 - 4s - loss: 1.5498 - accuracy: 0.6120
#
# Epoch 00085: loss improved from 1.56586 to 1.54982, saving model to weights-improvement-85-1.5498-bigger.hdf5
# Epoch 86/250
# 454/454 - 5s - loss: 1.5341 - accuracy: 0.6162
#
# Epoch 00086: loss improved from 1.54982 to 1.53415, saving model to weights-improvement-86-1.5341-bigger.hdf5
# Epoch 87/250
# 454/454 - 4s - loss: 1.5206 - accuracy: 0.6177
#
# Epoch 00087: loss improved from 1.53415 to 1.52055, saving model to weights-improvement-87-1.5206-bigger.hdf5
# Epoch 88/250
# 454/454 - 5s - loss: 1.5074 - accuracy: 0.6210
#
# Epoch 00088: loss improved from 1.52055 to 1.50741, saving model to weights-improvement-88-1.5074-bigger.hdf5
# Epoch 89/250
# 454/454 - 5s - loss: 1.4934 - accuracy: 0.6244
#
# Epoch 00089: loss improved from 1.50741 to 1.49337, saving model to weights-improvement-89-1.4934-bigger.hdf5
# Epoch 90/250
# 454/454 - 5s - loss: 1.4776 - accuracy: 0.6282
#
# Epoch 00090: loss improved from 1.49337 to 1.47755, saving model to weights-improvement-90-1.4776-bigger.hdf5
# Epoch 91/250
# 454/454 - 5s - loss: 1.4665 - accuracy: 0.6278
#
# Epoch 00091: loss improved from 1.47755 to 1.46651, saving model to weights-improvement-91-1.4665-bigger.hdf5
# Epoch 92/250
# 454/454 - 5s - loss: 1.4507 - accuracy: 0.6291
#
# Epoch 00092: loss improved from 1.46651 to 1.45072, saving model to weights-improvement-92-1.4507-bigger.hdf5
# Epoch 93/250
# 454/454 - 5s - loss: 1.4396 - accuracy: 0.6316
#
# Epoch 00093: loss improved from 1.45072 to 1.43963, saving model to weights-improvement-93-1.4396-bigger.hdf5
# Epoch 94/250
# 454/454 - 4s - loss: 1.4287 - accuracy: 0.6310
#
# Epoch 00094: loss improved from 1.43963 to 1.42869, saving model to weights-improvement-94-1.4287-bigger.hdf5
# Epoch 95/250
# 454/454 - 4s - loss: 1.4162 - accuracy: 0.6372
#
# Epoch 00095: loss improved from 1.42869 to 1.41625, saving model to weights-improvement-95-1.4162-bigger.hdf5
# Epoch 96/250
# 454/454 - 4s - loss: 1.4026 - accuracy: 0.6363
#
# Epoch 00096: loss improved from 1.41625 to 1.40264, saving model to weights-improvement-96-1.4026-bigger.hdf5
# Epoch 97/250
# 454/454 - 4s - loss: 1.3917 - accuracy: 0.6381
#
# Epoch 00097: loss improved from 1.40264 to 1.39171, saving model to weights-improvement-97-1.3917-bigger.hdf5
# Epoch 98/250
# 454/454 - 5s - loss: 1.3801 - accuracy: 0.6423
#
# Epoch 00098: loss improved from 1.39171 to 1.38015, saving model to weights-improvement-98-1.3801-bigger.hdf5
# Epoch 99/250
# 454/454 - 4s - loss: 1.3680 - accuracy: 0.6425
#
# Epoch 00099: loss improved from 1.38015 to 1.36802, saving model to weights-improvement-99-1.3680-bigger.hdf5
# Epoch 100/250
# 454/454 - 4s - loss: 1.3592 - accuracy: 0.6445
#
# Epoch 00100: loss improved from 1.36802 to 1.35922, saving model to weights-improvement-100-1.3592-bigger.hdf5
# Epoch 101/250
# 454/454 - 5s - loss: 1.3470 - accuracy: 0.6465
#
# Epoch 00101: loss improved from 1.35922 to 1.34701, saving model to weights-improvement-101-1.3470-bigger.hdf5
# Epoch 102/250
# 454/454 - 4s - loss: 1.3379 - accuracy: 0.6484
#
# Epoch 00102: loss improved from 1.34701 to 1.33792, saving model to weights-improvement-102-1.3379-bigger.hdf5
# Epoch 103/250
# 454/454 - 4s - loss: 1.3267 - accuracy: 0.6508
#
# Epoch 00103: loss improved from 1.33792 to 1.32673, saving model to weights-improvement-103-1.3267-bigger.hdf5
# Epoch 104/250
# 454/454 - 4s - loss: 1.3153 - accuracy: 0.6527
#
# Epoch 00104: loss improved from 1.32673 to 1.31527, saving model to weights-improvement-104-1.3153-bigger.hdf5
# Epoch 105/250
# 454/454 - 5s - loss: 1.3055 - accuracy: 0.6531
#
# Epoch 00105: loss improved from 1.31527 to 1.30549, saving model to weights-improvement-105-1.3055-bigger.hdf5
# Epoch 106/250
# 454/454 - 5s - loss: 1.2968 - accuracy: 0.6564
#
# Epoch 00106: loss improved from 1.30549 to 1.29679, saving model to weights-improvement-106-1.2968-bigger.hdf5
# Epoch 107/250
# 454/454 - 4s - loss: 1.2862 - accuracy: 0.6565
#
# Epoch 00107: loss improved from 1.29679 to 1.28618, saving model to weights-improvement-107-1.2862-bigger.hdf5
# Epoch 108/250
# 454/454 - 5s - loss: 1.2772 - accuracy: 0.6580
#
# Epoch 00108: loss improved from 1.28618 to 1.27720, saving model to weights-improvement-108-1.2772-bigger.hdf5
# Epoch 109/250
# 454/454 - 5s - loss: 1.2669 - accuracy: 0.6615
#
# Epoch 00109: loss improved from 1.27720 to 1.26689, saving model to weights-improvement-109-1.2669-bigger.hdf5
# Epoch 110/250
# 454/454 - 5s - loss: 1.2590 - accuracy: 0.6620
#
# Epoch 00110: loss improved from 1.26689 to 1.25902, saving model to weights-improvement-110-1.2590-bigger.hdf5
# Epoch 111/250
# 454/454 - 5s - loss: 1.2487 - accuracy: 0.6624
#
# Epoch 00111: loss improved from 1.25902 to 1.24869, saving model to weights-improvement-111-1.2487-bigger.hdf5
# Epoch 112/250
# 454/454 - 5s - loss: 1.2402 - accuracy: 0.6677
#
# Epoch 00112: loss improved from 1.24869 to 1.24023, saving model to weights-improvement-112-1.2402-bigger.hdf5
# Epoch 113/250
# 454/454 - 5s - loss: 1.2313 - accuracy: 0.6688
#
# Epoch 00113: loss improved from 1.24023 to 1.23128, saving model to weights-improvement-113-1.2313-bigger.hdf5
# Epoch 114/250
# 454/454 - 5s - loss: 1.2232 - accuracy: 0.6699
#
# Epoch 00114: loss improved from 1.23128 to 1.22322, saving model to weights-improvement-114-1.2232-bigger.hdf5
# Epoch 115/250
# 454/454 - 5s - loss: 1.2153 - accuracy: 0.6686
#
# Epoch 00115: loss improved from 1.22322 to 1.21530, saving model to weights-improvement-115-1.2153-bigger.hdf5
# Epoch 116/250
# 454/454 - 5s - loss: 1.2074 - accuracy: 0.6729
#
# Epoch 00116: loss improved from 1.21530 to 1.20743, saving model to weights-improvement-116-1.2074-bigger.hdf5
# Epoch 117/250
# 454/454 - 4s - loss: 1.1977 - accuracy: 0.6704
#
# Epoch 00117: loss improved from 1.20743 to 1.19772, saving model to weights-improvement-117-1.1977-bigger.hdf5
# Epoch 118/250
# 454/454 - 5s - loss: 1.1905 - accuracy: 0.6712
#
# Epoch 00118: loss improved from 1.19772 to 1.19047, saving model to weights-improvement-118-1.1905-bigger.hdf5
# Epoch 119/250
# 454/454 - 4s - loss: 1.1832 - accuracy: 0.6732
#
# Epoch 00119: loss improved from 1.19047 to 1.18317, saving model to weights-improvement-119-1.1832-bigger.hdf5
# Epoch 120/250
# 454/454 - 5s - loss: 1.1729 - accuracy: 0.6750
#
# Epoch 00120: loss improved from 1.18317 to 1.17290, saving model to weights-improvement-120-1.1729-bigger.hdf5
# Epoch 121/250
# 454/454 - 4s - loss: 1.1694 - accuracy: 0.6760
#
# Epoch 00121: loss improved from 1.17290 to 1.16936, saving model to weights-improvement-121-1.1694-bigger.hdf5
# Epoch 122/250
# 454/454 - 4s - loss: 1.1603 - accuracy: 0.6736
#
# Epoch 00122: loss improved from 1.16936 to 1.16026, saving model to weights-improvement-122-1.1603-bigger.hdf5
# Epoch 123/250
# 454/454 - 5s - loss: 1.1529 - accuracy: 0.6792
#
# Epoch 00123: loss improved from 1.16026 to 1.15286, saving model to weights-improvement-123-1.1529-bigger.hdf5
# Epoch 124/250
# 454/454 - 4s - loss: 1.1456 - accuracy: 0.6792
#
# Epoch 00124: loss improved from 1.15286 to 1.14559, saving model to weights-improvement-124-1.1456-bigger.hdf5
# Epoch 125/250
# 454/454 - 4s - loss: 1.1371 - accuracy: 0.6813
#
# Epoch 00125: loss improved from 1.14559 to 1.13707, saving model to weights-improvement-125-1.1371-bigger.hdf5
# Epoch 126/250
# 454/454 - 4s - loss: 1.1310 - accuracy: 0.6837
#
# Epoch 00126: loss improved from 1.13707 to 1.13105, saving model to weights-improvement-126-1.1310-bigger.hdf5
# Epoch 127/250
# 454/454 - 5s - loss: 1.1238 - accuracy: 0.6832
#
# Epoch 00127: loss improved from 1.13105 to 1.12378, saving model to weights-improvement-127-1.1238-bigger.hdf5
# Epoch 128/250
# 454/454 - 5s - loss: 1.1164 - accuracy: 0.6850
#
# Epoch 00128: loss improved from 1.12378 to 1.11641, saving model to weights-improvement-128-1.1164-bigger.hdf5
# Epoch 129/250
# 454/454 - 5s - loss: 1.1102 - accuracy: 0.6844
#
# Epoch 00129: loss improved from 1.11641 to 1.11022, saving model to weights-improvement-129-1.1102-bigger.hdf5
# Epoch 130/250
# 454/454 - 5s - loss: 1.1041 - accuracy: 0.6854
#
# Epoch 00130: loss improved from 1.11022 to 1.10409, saving model to weights-improvement-130-1.1041-bigger.hdf5
# Epoch 131/250
# 454/454 - 5s - loss: 1.0986 - accuracy: 0.6884
#
# Epoch 00131: loss improved from 1.10409 to 1.09862, saving model to weights-improvement-131-1.0986-bigger.hdf5
# Epoch 132/250
# 454/454 - 5s - loss: 1.0918 - accuracy: 0.6890
#
# Epoch 00132: loss improved from 1.09862 to 1.09179, saving model to weights-improvement-132-1.0918-bigger.hdf5
# Epoch 133/250
# 454/454 - 5s - loss: 1.0838 - accuracy: 0.6896
#
# Epoch 00133: loss improved from 1.09179 to 1.08378, saving model to weights-improvement-133-1.0838-bigger.hdf5
# Epoch 134/250
# 454/454 - 5s - loss: 1.0761 - accuracy: 0.6925
#
# Epoch 00134: loss improved from 1.08378 to 1.07614, saving model to weights-improvement-134-1.0761-bigger.hdf5
# Epoch 135/250
# 454/454 - 5s - loss: 1.0736 - accuracy: 0.6895
#
# Epoch 00135: loss improved from 1.07614 to 1.07357, saving model to weights-improvement-135-1.0736-bigger.hdf5
# Epoch 136/250
# 454/454 - 5s - loss: 1.0664 - accuracy: 0.6951
#
# Epoch 00136: loss improved from 1.07357 to 1.06639, saving model to weights-improvement-136-1.0664-bigger.hdf5
# Epoch 137/250
# 454/454 - 5s - loss: 1.0608 - accuracy: 0.6927
#
# Epoch 00137: loss improved from 1.06639 to 1.06082, saving model to weights-improvement-137-1.0608-bigger.hdf5
# Epoch 138/250
# 454/454 - 5s - loss: 1.0551 - accuracy: 0.6931
#
# Epoch 00138: loss improved from 1.06082 to 1.05507, saving model to weights-improvement-138-1.0551-bigger.hdf5
# Epoch 139/250
# 454/454 - 5s - loss: 1.0477 - accuracy: 0.6949
#
# Epoch 00139: loss improved from 1.05507 to 1.04766, saving model to weights-improvement-139-1.0477-bigger.hdf5
# Epoch 140/250
# 454/454 - 5s - loss: 1.0418 - accuracy: 0.6963
#
# Epoch 00140: loss improved from 1.04766 to 1.04176, saving model to weights-improvement-140-1.0418-bigger.hdf5
# Epoch 141/250
# 454/454 - 5s - loss: 1.0391 - accuracy: 0.6963
#
# Epoch 00141: loss improved from 1.04176 to 1.03908, saving model to weights-improvement-141-1.0391-bigger.hdf5
# Epoch 142/250
# 454/454 - 5s - loss: 1.0323 - accuracy: 0.6979
#
# Epoch 00142: loss improved from 1.03908 to 1.03231, saving model to weights-improvement-142-1.0323-bigger.hdf5
# Epoch 143/250
# 454/454 - 5s - loss: 1.0261 - accuracy: 0.6993
#
# Epoch 00143: loss improved from 1.03231 to 1.02607, saving model to weights-improvement-143-1.0261-bigger.hdf5
# Epoch 144/250
# 454/454 - 5s - loss: 1.0210 - accuracy: 0.6985
#
# Epoch 00144: loss improved from 1.02607 to 1.02102, saving model to weights-improvement-144-1.0210-bigger.hdf5
# Epoch 145/250
# 454/454 - 5s - loss: 1.0173 - accuracy: 0.6960
#
# Epoch 00145: loss improved from 1.02102 to 1.01734, saving model to weights-improvement-145-1.0173-bigger.hdf5
# Epoch 146/250
# 454/454 - 5s - loss: 1.0110 - accuracy: 0.7009
#
# Epoch 00146: loss improved from 1.01734 to 1.01101, saving model to weights-improvement-146-1.0110-bigger.hdf5
# Epoch 147/250
# 454/454 - 5s - loss: 1.0056 - accuracy: 0.6994
#
# Epoch 00147: loss improved from 1.01101 to 1.00557, saving model to weights-improvement-147-1.0056-bigger.hdf5
# Epoch 148/250
# 454/454 - 5s - loss: 1.0010 - accuracy: 0.7050
#
# Epoch 00148: loss improved from 1.00557 to 1.00096, saving model to weights-improvement-148-1.0010-bigger.hdf5
# Epoch 149/250
# 454/454 - 5s - loss: 0.9962 - accuracy: 0.7039
#
# Epoch 00149: loss improved from 1.00096 to 0.99616, saving model to weights-improvement-149-0.9962-bigger.hdf5
# Epoch 150/250
# 454/454 - 4s - loss: 0.9908 - accuracy: 0.7036
#
# Epoch 00150: loss improved from 0.99616 to 0.99080, saving model to weights-improvement-150-0.9908-bigger.hdf5
# Epoch 151/250
# 454/454 - 5s - loss: 0.9859 - accuracy: 0.7017
#
# Epoch 00151: loss improved from 0.99080 to 0.98592, saving model to weights-improvement-151-0.9859-bigger.hdf5
# Epoch 152/250
# 454/454 - 5s - loss: 0.9823 - accuracy: 0.7039
#
# Epoch 00152: loss improved from 0.98592 to 0.98227, saving model to weights-improvement-152-0.9823-bigger.hdf5
# Epoch 153/250
# 454/454 - 5s - loss: 0.9773 - accuracy: 0.7069
#
# Epoch 00153: loss improved from 0.98227 to 0.97729, saving model to weights-improvement-153-0.9773-bigger.hdf5
# Epoch 154/250
# 454/454 - 5s - loss: 0.9700 - accuracy: 0.7060
#
# Epoch 00154: loss improved from 0.97729 to 0.97003, saving model to weights-improvement-154-0.9700-bigger.hdf5
# Epoch 155/250
# 454/454 - 5s - loss: 0.9662 - accuracy: 0.7079
#
# Epoch 00155: loss improved from 0.97003 to 0.96625, saving model to weights-improvement-155-0.9662-bigger.hdf5
# Epoch 156/250
# 454/454 - 5s - loss: 0.9621 - accuracy: 0.7075
#
# Epoch 00156: loss improved from 0.96625 to 0.96209, saving model to weights-improvement-156-0.9621-bigger.hdf5
# Epoch 157/250
# 454/454 - 5s - loss: 0.9582 - accuracy: 0.7095
#
# Epoch 00157: loss improved from 0.96209 to 0.95824, saving model to weights-improvement-157-0.9582-bigger.hdf5
# Epoch 158/250
# 454/454 - 5s - loss: 0.9532 - accuracy: 0.7093
#
# Epoch 00158: loss improved from 0.95824 to 0.95318, saving model to weights-improvement-158-0.9532-bigger.hdf5
# Epoch 159/250
# 454/454 - 5s - loss: 0.9485 - accuracy: 0.7113
#
# Epoch 00159: loss improved from 0.95318 to 0.94847, saving model to weights-improvement-159-0.9485-bigger.hdf5
# Epoch 160/250
# 454/454 - 5s - loss: 0.9455 - accuracy: 0.7124
#
# Epoch 00160: loss improved from 0.94847 to 0.94548, saving model to weights-improvement-160-0.9455-bigger.hdf5
# Epoch 161/250
# 454/454 - 5s - loss: 0.9385 - accuracy: 0.7109
#
# Epoch 00161: loss improved from 0.94548 to 0.93851, saving model to weights-improvement-161-0.9385-bigger.hdf5
# Epoch 162/250
# 454/454 - 5s - loss: 0.9380 - accuracy: 0.7106
#
# Epoch 00162: loss improved from 0.93851 to 0.93796, saving model to weights-improvement-162-0.9380-bigger.hdf5
# Epoch 163/250
# 454/454 - 5s - loss: 0.9303 - accuracy: 0.7133
#
# Epoch 00163: loss improved from 0.93796 to 0.93025, saving model to weights-improvement-163-0.9303-bigger.hdf5
# Epoch 164/250
# 454/454 - 5s - loss: 0.9292 - accuracy: 0.7144
#
# Epoch 00164: loss improved from 0.93025 to 0.92917, saving model to weights-improvement-164-0.9292-bigger.hdf5
# Epoch 165/250
# 454/454 - 5s - loss: 0.9226 - accuracy: 0.7142
#
# Epoch 00165: loss improved from 0.92917 to 0.92259, saving model to weights-improvement-165-0.9226-bigger.hdf5
# Epoch 166/250
# 454/454 - 5s - loss: 0.9200 - accuracy: 0.7142
#
# Epoch 00166: loss improved from 0.92259 to 0.91999, saving model to weights-improvement-166-0.9200-bigger.hdf5
# Epoch 167/250
# 454/454 - 5s - loss: 0.9161 - accuracy: 0.7169
#
# Epoch 00167: loss improved from 0.91999 to 0.91610, saving model to weights-improvement-167-0.9161-bigger.hdf5
# Epoch 168/250
# 454/454 - 9s - loss: 0.9125 - accuracy: 0.7140
#
# Epoch 00168: loss improved from 0.91610 to 0.91249, saving model to weights-improvement-168-0.9125-bigger.hdf5
# Epoch 169/250
# 454/454 - 9s - loss: 0.9091 - accuracy: 0.7155
#
# Epoch 00169: loss improved from 0.91249 to 0.90910, saving model to weights-improvement-169-0.9091-bigger.hdf5
# Epoch 170/250
# 454/454 - 6s - loss: 0.9030 - accuracy: 0.7175
#
# Epoch 00170: loss improved from 0.90910 to 0.90301, saving model to weights-improvement-170-0.9030-bigger.hdf5
# Epoch 171/250
# 454/454 - 5s - loss: 0.9021 - accuracy: 0.7188
#
# Epoch 00171: loss improved from 0.90301 to 0.90205, saving model to weights-improvement-171-0.9021-bigger.hdf5
# Epoch 172/250
# 454/454 - 5s - loss: 0.8981 - accuracy: 0.7166
#
# Epoch 00172: loss improved from 0.90205 to 0.89811, saving model to weights-improvement-172-0.8981-bigger.hdf5
# Epoch 173/250
# 454/454 - 4s - loss: 0.8944 - accuracy: 0.7180
#
# Epoch 00173: loss improved from 0.89811 to 0.89444, saving model to weights-improvement-173-0.8944-bigger.hdf5
# Epoch 174/250
# 454/454 - 5s - loss: 0.8915 - accuracy: 0.7202
#
# Epoch 00174: loss improved from 0.89444 to 0.89148, saving model to weights-improvement-174-0.8915-bigger.hdf5
# Epoch 175/250
# 454/454 - 5s - loss: 0.8874 - accuracy: 0.7206
#
# Epoch 00175: loss improved from 0.89148 to 0.88745, saving model to weights-improvement-175-0.8874-bigger.hdf5
# Epoch 176/250
# 454/454 - 5s - loss: 0.8820 - accuracy: 0.7216
#
# Epoch 00176: loss improved from 0.88745 to 0.88200, saving model to weights-improvement-176-0.8820-bigger.hdf5
# Epoch 177/250
# 454/454 - 5s - loss: 0.8801 - accuracy: 0.7197
#
# Epoch 00177: loss improved from 0.88200 to 0.88014, saving model to weights-improvement-177-0.8801-bigger.hdf5
# Epoch 178/250
# 454/454 - 5s - loss: 0.8765 - accuracy: 0.7193
#
# Epoch 00178: loss improved from 0.88014 to 0.87646, saving model to weights-improvement-178-0.8765-bigger.hdf5
# Epoch 179/250
# 454/454 - 5s - loss: 0.8727 - accuracy: 0.7213
#
# Epoch 00179: loss improved from 0.87646 to 0.87272, saving model to weights-improvement-179-0.8727-bigger.hdf5
# Epoch 180/250
# 454/454 - 5s - loss: 0.8716 - accuracy: 0.7218
#
# Epoch 00180: loss improved from 0.87272 to 0.87158, saving model to weights-improvement-180-0.8716-bigger.hdf5
# Epoch 181/250
# 454/454 - 6s - loss: 0.8658 - accuracy: 0.7210
#
# Epoch 00181: loss improved from 0.87158 to 0.86580, saving model to weights-improvement-181-0.8658-bigger.hdf5
# Epoch 182/250
# 454/454 - 5s - loss: 0.8620 - accuracy: 0.7224
#
# Epoch 00182: loss improved from 0.86580 to 0.86200, saving model to weights-improvement-182-0.8620-bigger.hdf5
# Epoch 183/250
# 454/454 - 5s - loss: 0.8603 - accuracy: 0.7204
#
# Epoch 00183: loss improved from 0.86200 to 0.86027, saving model to weights-improvement-183-0.8603-bigger.hdf5
# Epoch 184/250
# 454/454 - 5s - loss: 0.8571 - accuracy: 0.7222
#
# Epoch 00184: loss improved from 0.86027 to 0.85708, saving model to weights-improvement-184-0.8571-bigger.hdf5
# Epoch 185/250
# 454/454 - 5s - loss: 0.8526 - accuracy: 0.7274
#
# Epoch 00185: loss improved from 0.85708 to 0.85263, saving model to weights-improvement-185-0.8526-bigger.hdf5
# Epoch 186/250
# 454/454 - 5s - loss: 0.8503 - accuracy: 0.7236
#
# Epoch 00186: loss improved from 0.85263 to 0.85031, saving model to weights-improvement-186-0.8503-bigger.hdf5
# Epoch 187/250
# 454/454 - 5s - loss: 0.8471 - accuracy: 0.7237
#
# Epoch 00187: loss improved from 0.85031 to 0.84706, saving model to weights-improvement-187-0.8471-bigger.hdf5
# Epoch 188/250
# 454/454 - 6s - loss: 0.8454 - accuracy: 0.7261
#
# Epoch 00188: loss improved from 0.84706 to 0.84536, saving model to weights-improvement-188-0.8454-bigger.hdf5
# Epoch 189/250
# 454/454 - 5s - loss: 0.8401 - accuracy: 0.7279
#
# Epoch 00189: loss improved from 0.84536 to 0.84014, saving model to weights-improvement-189-0.8401-bigger.hdf5
# Epoch 190/250
# 454/454 - 5s - loss: 0.8391 - accuracy: 0.7233
#
# Epoch 00190: loss improved from 0.84014 to 0.83912, saving model to weights-improvement-190-0.8391-bigger.hdf5
# Epoch 191/250
# 454/454 - 5s - loss: 0.8355 - accuracy: 0.7268
#
# Epoch 00191: loss improved from 0.83912 to 0.83545, saving model to weights-improvement-191-0.8355-bigger.hdf5
# Epoch 192/250
# 454/454 - 5s - loss: 0.8326 - accuracy: 0.7279
#
# Epoch 00192: loss improved from 0.83545 to 0.83257, saving model to weights-improvement-192-0.8326-bigger.hdf5
# Epoch 193/250
# 454/454 - 5s - loss: 0.8296 - accuracy: 0.7261
#
# Epoch 00193: loss improved from 0.83257 to 0.82963, saving model to weights-improvement-193-0.8296-bigger.hdf5
# Epoch 194/250
# 454/454 - 5s - loss: 0.8285 - accuracy: 0.7263
#
# Epoch 00194: loss improved from 0.82963 to 0.82846, saving model to weights-improvement-194-0.8285-bigger.hdf5
# Epoch 195/250
# 454/454 - 5s - loss: 0.8211 - accuracy: 0.7288
#
# Epoch 00195: loss improved from 0.82846 to 0.82115, saving model to weights-improvement-195-0.8211-bigger.hdf5
# Epoch 196/250
# 454/454 - 5s - loss: 0.8213 - accuracy: 0.7268
#
# Epoch 00196: loss did not improve from 0.82115
# Epoch 197/250
# 454/454 - 5s - loss: 0.8178 - accuracy: 0.7299
#
# Epoch 00197: loss improved from 0.82115 to 0.81780, saving model to weights-improvement-197-0.8178-bigger.hdf5
# Epoch 198/250
# 454/454 - 5s - loss: 0.8154 - accuracy: 0.7283
#
# Epoch 00198: loss improved from 0.81780 to 0.81536, saving model to weights-improvement-198-0.8154-bigger.hdf5
# Epoch 199/250
# 454/454 - 5s - loss: 0.8134 - accuracy: 0.7302
#
# Epoch 00199: loss improved from 0.81536 to 0.81344, saving model to weights-improvement-199-0.8134-bigger.hdf5
# Epoch 200/250
# 454/454 - 5s - loss: 0.8099 - accuracy: 0.7297
#
# Epoch 00200: loss improved from 0.81344 to 0.80988, saving model to weights-improvement-200-0.8099-bigger.hdf5
# Epoch 201/250
# 454/454 - 7s - loss: 0.8086 - accuracy: 0.7296
#
# Epoch 00201: loss improved from 0.80988 to 0.80859, saving model to weights-improvement-201-0.8086-bigger.hdf5
# Epoch 202/250
# 454/454 - 5s - loss: 0.8046 - accuracy: 0.7301
#
# Epoch 00202: loss improved from 0.80859 to 0.80462, saving model to weights-improvement-202-0.8046-bigger.hdf5
# Epoch 203/250
# 454/454 - 5s - loss: 0.8023 - accuracy: 0.7317
#
# Epoch 00203: loss improved from 0.80462 to 0.80231, saving model to weights-improvement-203-0.8023-bigger.hdf5
# Epoch 204/250
# 454/454 - 5s - loss: 0.8025 - accuracy: 0.7297
#
# Epoch 00204: loss did not improve from 0.80231
# Epoch 205/250
# 454/454 - 5s - loss: 0.7966 - accuracy: 0.7332
#
# Epoch 00205: loss improved from 0.80231 to 0.79662, saving model to weights-improvement-205-0.7966-bigger.hdf5
# Epoch 206/250
# 454/454 - 5s - loss: 0.7944 - accuracy: 0.7297
#
# Epoch 00206: loss improved from 0.79662 to 0.79439, saving model to weights-improvement-206-0.7944-bigger.hdf5
# Epoch 207/250
# 454/454 - 5s - loss: 0.7934 - accuracy: 0.7305
#
# Epoch 00207: loss improved from 0.79439 to 0.79342, saving model to weights-improvement-207-0.7934-bigger.hdf5
# Epoch 208/250
# 454/454 - 5s - loss: 0.7906 - accuracy: 0.7330
#
# Epoch 00208: loss improved from 0.79342 to 0.79064, saving model to weights-improvement-208-0.7906-bigger.hdf5
# Epoch 209/250
# 454/454 - 5s - loss: 0.7872 - accuracy: 0.7335
#
# Epoch 00209: loss improved from 0.79064 to 0.78716, saving model to weights-improvement-209-0.7872-bigger.hdf5
# Epoch 210/250
# 454/454 - 5s - loss: 0.7851 - accuracy: 0.7323
#
# Epoch 00210: loss improved from 0.78716 to 0.78508, saving model to weights-improvement-210-0.7851-bigger.hdf5
# Epoch 211/250
# 454/454 - 5s - loss: 0.7831 - accuracy: 0.7324
#
# Epoch 00211: loss improved from 0.78508 to 0.78308, saving model to weights-improvement-211-0.7831-bigger.hdf5
# Epoch 212/250
# 454/454 - 5s - loss: 0.7806 - accuracy: 0.7352
#
# Epoch 00212: loss improved from 0.78308 to 0.78059, saving model to weights-improvement-212-0.7806-bigger.hdf5
# Epoch 213/250
# 454/454 - 5s - loss: 0.7798 - accuracy: 0.7327
#
# Epoch 00213: loss improved from 0.78059 to 0.77982, saving model to weights-improvement-213-0.7798-bigger.hdf5
# Epoch 214/250
# 454/454 - 5s - loss: 0.7770 - accuracy: 0.7323
#
# Epoch 00214: loss improved from 0.77982 to 0.77698, saving model to weights-improvement-214-0.7770-bigger.hdf5
# Epoch 215/250
# 454/454 - 5s - loss: 0.7722 - accuracy: 0.7321
#
# Epoch 00215: loss improved from 0.77698 to 0.77223, saving model to weights-improvement-215-0.7722-bigger.hdf5
# Epoch 216/250
# 454/454 - 4s - loss: 0.7715 - accuracy: 0.7344
#
# Epoch 00216: loss improved from 0.77223 to 0.77148, saving model to weights-improvement-216-0.7715-bigger.hdf5
# Epoch 217/250
# 454/454 - 5s - loss: 0.7709 - accuracy: 0.7312
#
# Epoch 00217: loss improved from 0.77148 to 0.77087, saving model to weights-improvement-217-0.7709-bigger.hdf5
# Epoch 218/250
# 454/454 - 5s - loss: 0.7666 - accuracy: 0.7345
#
# Epoch 00218: loss improved from 0.77087 to 0.76658, saving model to weights-improvement-218-0.7666-bigger.hdf5
# Epoch 219/250
# 454/454 - 5s - loss: 0.7657 - accuracy: 0.7349
#
# Epoch 00219: loss improved from 0.76658 to 0.76573, saving model to weights-improvement-219-0.7657-bigger.hdf5
# Epoch 220/250
# 454/454 - 5s - loss: 0.7623 - accuracy: 0.7350
#
# Epoch 00220: loss improved from 0.76573 to 0.76227, saving model to weights-improvement-220-0.7623-bigger.hdf5
# Epoch 221/250
# 454/454 - 5s - loss: 0.7613 - accuracy: 0.7352
#
# Epoch 00221: loss improved from 0.76227 to 0.76125, saving model to weights-improvement-221-0.7613-bigger.hdf5
# Epoch 222/250
# 454/454 - 5s - loss: 0.7590 - accuracy: 0.7349
#
# Epoch 00222: loss improved from 0.76125 to 0.75904, saving model to weights-improvement-222-0.7590-bigger.hdf5
# Epoch 223/250
# 454/454 - 5s - loss: 0.7561 - accuracy: 0.7361
#
# Epoch 00223: loss improved from 0.75904 to 0.75615, saving model to weights-improvement-223-0.7561-bigger.hdf5
# Epoch 224/250
# 454/454 - 5s - loss: 0.7545 - accuracy: 0.7338
#
# Epoch 00224: loss improved from 0.75615 to 0.75451, saving model to weights-improvement-224-0.7545-bigger.hdf5
# Epoch 225/250
# 454/454 - 5s - loss: 0.7539 - accuracy: 0.7374
#
# Epoch 00225: loss improved from 0.75451 to 0.75388, saving model to weights-improvement-225-0.7539-bigger.hdf5
# Epoch 226/250
# 454/454 - 5s - loss: 0.7507 - accuracy: 0.7365
#
# Epoch 00226: loss improved from 0.75388 to 0.75069, saving model to weights-improvement-226-0.7507-bigger.hdf5
# Epoch 227/250
# 454/454 - 5s - loss: 0.7481 - accuracy: 0.7368
#
# Epoch 00227: loss improved from 0.75069 to 0.74807, saving model to weights-improvement-227-0.7481-bigger.hdf5
# Epoch 228/250
# 454/454 - 5s - loss: 0.7452 - accuracy: 0.7363
#
# Epoch 00228: loss improved from 0.74807 to 0.74524, saving model to weights-improvement-228-0.7452-bigger.hdf5
# Epoch 229/250
# 454/454 - 5s - loss: 0.7468 - accuracy: 0.7365
#
# Epoch 00229: loss did not improve from 0.74524
# Epoch 230/250
# 454/454 - 5s - loss: 0.7427 - accuracy: 0.7365
#
# Epoch 00230: loss improved from 0.74524 to 0.74271, saving model to weights-improvement-230-0.7427-bigger.hdf5
# Epoch 231/250
# 454/454 - 5s - loss: 0.7403 - accuracy: 0.7383
#
# Epoch 00231: loss improved from 0.74271 to 0.74034, saving model to weights-improvement-231-0.7403-bigger.hdf5
# Epoch 232/250
# 454/454 - 5s - loss: 0.7397 - accuracy: 0.7362
#
# Epoch 00232: loss improved from 0.74034 to 0.73974, saving model to weights-improvement-232-0.7397-bigger.hdf5
# Epoch 233/250
# 454/454 - 5s - loss: 0.7376 - accuracy: 0.7379
#
# Epoch 00233: loss improved from 0.73974 to 0.73756, saving model to weights-improvement-233-0.7376-bigger.hdf5
# Epoch 234/250
# 454/454 - 5s - loss: 0.7345 - accuracy: 0.7354
#
# Epoch 00234: loss improved from 0.73756 to 0.73454, saving model to weights-improvement-234-0.7345-bigger.hdf5
# Epoch 235/250
# 454/454 - 5s - loss: 0.7348 - accuracy: 0.7366
#
# Epoch 00235: loss did not improve from 0.73454
# Epoch 236/250
# 454/454 - 5s - loss: 0.7316 - accuracy: 0.7373
#
# Epoch 00236: loss improved from 0.73454 to 0.73164, saving model to weights-improvement-236-0.7316-bigger.hdf5
# Epoch 237/250
# 454/454 - 5s - loss: 0.7280 - accuracy: 0.7398
#
# Epoch 00237: loss improved from 0.73164 to 0.72796, saving model to weights-improvement-237-0.7280-bigger.hdf5
# Epoch 238/250
# 454/454 - 5s - loss: 0.7281 - accuracy: 0.7370
#
# Epoch 00238: loss did not improve from 0.72796
# Epoch 239/250
# 454/454 - 5s - loss: 0.7267 - accuracy: 0.7365
#
# Epoch 00239: loss improved from 0.72796 to 0.72672, saving model to weights-improvement-239-0.7267-bigger.hdf5
# Epoch 240/250
# 454/454 - 5s - loss: 0.7247 - accuracy: 0.7372
#
# Epoch 00240: loss improved from 0.72672 to 0.72469, saving model to weights-improvement-240-0.7247-bigger.hdf5
# Epoch 241/250
# 454/454 - 5s - loss: 0.7243 - accuracy: 0.7391
#
# Epoch 00241: loss improved from 0.72469 to 0.72428, saving model to weights-improvement-241-0.7243-bigger.hdf5
# Epoch 242/250
# 454/454 - 5s - loss: 0.7218 - accuracy: 0.7374
#
# Epoch 00242: loss improved from 0.72428 to 0.72182, saving model to weights-improvement-242-0.7218-bigger.hdf5
# Epoch 243/250
# 454/454 - 5s - loss: 0.7187 - accuracy: 0.7397
#
# Epoch 00243: loss improved from 0.72182 to 0.71868, saving model to weights-improvement-243-0.7187-bigger.hdf5
# Epoch 244/250
# 454/454 - 5s - loss: 0.7176 - accuracy: 0.7414
#
# Epoch 00244: loss improved from 0.71868 to 0.71763, saving model to weights-improvement-244-0.7176-bigger.hdf5
# Epoch 245/250
# 454/454 - 5s - loss: 0.7165 - accuracy: 0.7389
#
# Epoch 00245: loss improved from 0.71763 to 0.71654, saving model to weights-improvement-245-0.7165-bigger.hdf5
# Epoch 246/250
# 454/454 - 5s - loss: 0.7141 - accuracy: 0.7401
#
# Epoch 00246: loss improved from 0.71654 to 0.71406, saving model to weights-improvement-246-0.7141-bigger.hdf5
# Epoch 247/250
# 454/454 - 5s - loss: 0.7129 - accuracy: 0.7400
#
# Epoch 00247: loss improved from 0.71406 to 0.71287, saving model to weights-improvement-247-0.7129-bigger.hdf5
# Epoch 248/250
# 454/454 - 5s - loss: 0.7113 - accuracy: 0.7432
#
# Epoch 00248: loss improved from 0.71287 to 0.71128, saving model to weights-improvement-248-0.7113-bigger.hdf5
# Epoch 249/250
# 454/454 - 5s - loss: 0.7114 - accuracy: 0.7415
#
# Epoch 00249: loss did not improve from 0.71128
# Epoch 250/250
# 454/454 - 5s - loss: 0.7097 - accuracy: 0.7385
#
# Epoch 00250: loss improved from 0.71128 to 0.70974, saving model to weights-improvement-250-0.7097-bigger.hdf5

# %%
import matplotlib.pyplot as plt

# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
#filename = "weights-improvement-250-0.6878-bigger.hdf5"
#model.load_weights(filename)
#model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
#Creating Interface with Gradio to interact with the model
# output_text = gr.outputs.Textbox()
# gr.Interface(generate,
#     [
#         gr.inputs.Textbox(label="seed_text"),
#         gr.inputs.Textbox(label="n"),
#     ],
#     output_text).launch(debug=True)

# %%
print(generate_seq(model, tokenizer, max_length-1, 'सितारे दिन में', 40))
print(generate_seq(model, tokenizer, max_length-1, 'खुशी', 1))
print(generate_seq(model, tokenizer, max_length-1, 'आपसे मिलकर', 1))
print(generate_seq(model, tokenizer, max_length-1, 'मेरे लिए', 1))
# Out:
# सितारे दिन में तारे गिन रही थीं लोग कहते हैं कि सबकी ज़िदगी में ये एक्सपेरीमेंट करते देख लिया ना तो माँ उसकी माँ नहीं सहेली बन जाती है। अरे हमने तो खाया ही नहीं मिला ऐक्चुली राहुल की जगह मिल जाए। चलो रात गुजारने का बन्दोबस्त हो गया चलो आज भौजी ने इतने जतन से सँवारा सजाया बात हमारे मुन्ना की थी। देखो ज्योति मैं ठहरा तड़ीपार आदमी और बेवज़ह किसी लफड़े में नहीं आएगी। इसलिए बेहतर यही है श्यामलाल जी पचास हज़ार रुपये ऊपर से और माँगता सर हाँ श्यामलाल जी पचास हज़ार रुपये ऊपर से और माँगता सर हाँ श्यामलाल जी पचास हज़ार रुपये ऊपर से और माँगता सर हाँ श्यामलाल जी पचास हज़ार रुपये ऊपर से और माँगता सर हाँ श्यामलाल जी पचास हज़ार रुपये ऊपर से और माँगता सर हाँ श्यामलाल जी पचास हज़ार रुपये ऊपर से और माँगता सर हाँ श्यामलाल जी पचास हज़ार रुपये ऊपर से और माँगता सर हाँ श्यामलाल जी पचास हज़ार रुपये ऊपर से और माँगता सर हाँ श्यामलाल जी पचास हज़ार रुपये ऊपर से और माँगता सर हाँ श्यामलाल जी पचास हज़ार रुपये ऊपर से और माँगता सर हाँ श्यामलाल जी पचास हज़ार रुपये ऊपर से और माँगता सर हाँ श्यामलाल जी पचास हज़ार रुपये ऊपर से और माँगता सर हाँ श्यामलाल जी पचास हज़ार रुपये ऊपर से और माँगता सर हाँ श्यामलाल जी पचास हज़ार रुपये ऊपर से और माँगता सर हाँ श्यामलाल जी पचास हज़ार रुपये ऊपर से और माँगता सर हाँ श्यामलाल जी पचास हज़ार रुपये ऊपर से और माँगता सर हाँ श्यामलाल जी पचास हज़ार रुपये ऊपर से और माँगता सर हाँ श्यामलाल जी पचास हज़ार रुपये ऊपर से और माँगता सर हाँ श्यामलाल जी पचास हज़ार रुपये ऊपर से और माँगता सर हाँ श्यामलाल जी पचास हज़ार रुपये ऊपर से और माँगता सर हाँ श्यामलाल जी पचास हज़ार रुपये ऊपर से और माँगता सर हाँ श्यामलाल जी पचास हज़ार रुपये ऊपर से और माँगता सर हाँ श्यामलाल जी पचास हज़ार रुपये ऊपर से और माँगता सर हाँ श्यामलाल जी पचास हज़ार रुपये ऊपर से और माँगता सर हाँ श्यामलाल जी पचास हज़ार रुपये ऊपर से और माँगता सर हाँ श्यामलाल जी पचास हज़ार रुपये ऊपर से और माँगता सर हाँ श्यामलाल जी पचास हज़ार रुपये ऊपर से और माँगता सर हाँ श्यामलाल जी पचास हज़ार रुपये ऊपर से और माँगता सर हाँ श्यामलाल जी पचास हज़ार रुपये ऊपर से और माँगता सर हाँ श्यामलाल जी पचास हज़ार
# खुशी हैं
# आपसे मिलकर खुशी
# मेरे लिए सिर्फ
